# %%
import numpy as np

R = np.array([[4, np.NaN, np.NaN, 2, np.NaN],
             [np.NaN, 5, np.NaN, 3, 1],
             [np.NaN, np.NaN, 3, 4, 4],
             [5, 2, 1, 2, np.NaN]])

num_users, num_items = R.shape
K=3

np.random.seed(1)
P = np.random.normal(scale=1./K, size = (num_users, K))
Q = np.random.normal(scale=1./K, size = (num_items, K))

# %%
from sklearn.metrics import mean_squared_error

def get_rmse(R,P,Q,non_zeros):
    error = 0
    full_pred_matrix = np.dot(P, Q.T)
    
    x_non_zero_ind = [non_zero[0] for non_zero in non_zeros]
    y_non_zero_ind = [non_zero[1] for non_zero in non_zeros]
    R_non_zeros = R[x_non_zero_ind, y_non_zero_ind]
    full_pred_matrix_non_zeros = full_pred_matrix[x_non_zero_ind, y_non_zero_ind]
    mse = mean_squared_error(R_non_zeros, full_pred_matrix_non_zeros)
    rmse = np.sqrt(mse)
    
    return mse

# %%
non_zeros = [(i,j,R[i,j]) for i in range(num_users) for j in range(num_items) if R[i,j] > 0 ]

steps = 1000
learning_rate = 0.01
r_lambda = 0.01

for step in range(steps):
    for i, j, r in non_zeros:
        eij = r - np.dot(P[i,:], Q[j,:].T)
        P[i,:] = P[i,:] + learning_rate*(eij * Q[j,:] - r_lambda*P[i,:])
        Q[j,:] = Q[j,:] + learning_rate*(eij * P[i,:] - r_lambda*Q[j,:])
        rmse = get_rmse(R, P, Q, non_zeros)
        if (step % 50) == 0 :
            print("### iteration step : ", step, " rmse : ", rmse)
# Out:
# ### iteration step :  0  rmse :  10.636436824054075
# ### iteration step :  0  rmse :  10.63021188824725
# ### iteration step :  0  rmse :  10.588414505005085
# ### iteration step :  0  rmse :  10.576534154532787
# ### iteration step :  0  rmse :  10.577684928273099
# ### iteration step :  0  rmse :  10.56947042640335
# ### iteration step :  0  rmse :  10.557593058694795
# ### iteration step :  0  rmse :  10.545713778795802
# ### iteration step :  0  rmse :  10.51008454903946
# ### iteration step :  0  rmse :  10.497894263795414
# ### iteration step :  0  rmse :  10.498680507861131
# ### iteration step :  0  rmse :  10.489858008094606
# ### iteration step :  50  rmse :  0.25031919103920597
# ### iteration step :  50  rmse :  0.25016165525667544
# ### iteration step :  50  rmse :  0.24899702001763332
# ### iteration step :  50  rmse :  0.24884967132378844
# ### iteration step :  50  rmse :  0.24895299109551006
# ### iteration step :  50  rmse :  0.2483351492963937
# ### iteration step :  50  rmse :  0.24841736164175987
# ### iteration step :  50  rmse :  0.24793029729582036
# ### iteration step :  50  rmse :  0.2401593493990274
# ### iteration step :  50  rmse :  0.23915721071224616
# ### iteration step :  50  rmse :  0.23881963652644858
# ### iteration step :  50  rmse :  0.2378242820743239
# ### iteration step :  100  rmse :  0.025317653199301886
# ### iteration step :  100  rmse :  0.02522034986530093
# ### iteration step :  100  rmse :  0.02519868037166459
# ### iteration step :  100  rmse :  0.025054361331618685
# ### iteration step :  100  rmse :  0.02506145288607241
# ### iteration step :  100  rmse :  0.025055195394457937
# ### iteration step :  100  rmse :  0.024924474239957844
# ### iteration step :  100  rmse :  0.02493895887952324
# ### iteration step :  100  rmse :  0.024728333708625566
# ### iteration step :  100  rmse :  0.02468249684948955
# ### iteration step :  100  rmse :  0.02461840123482589
# ### iteration step :  100  rmse :  0.024471608395764264
# ### iteration step :  150  rmse :  0.005694218957751494
# ### iteration step :  150  rmse :  0.005692082519252835
# ### iteration step :  150  rmse :  0.005690038415205605
# ### iteration step :  150  rmse :  0.005647222914340733
# ### iteration step :  150  rmse :  0.005653337143624089
# ### iteration step :  150  rmse :  0.005659386657874153
# ### iteration step :  150  rmse :  0.005608989705369528
# ### iteration step :  150  rmse :  0.005615104994337687
# ### iteration step :  150  rmse :  0.005569182422315133
# ### iteration step :  150  rmse :  0.005571625417620576
# ### iteration step :  150  rmse :  0.0055717889020306015
# ### iteration step :  150  rmse :  0.0055579131981562
# ### iteration step :  200  rmse :  0.0019018465606142536
# ### iteration step :  200  rmse :  0.0019104881056344423
# ### iteration step :  200  rmse :  0.0019088791039185585
# ### iteration step :  200  rmse :  0.0018901234332183291
# ### iteration step :  200  rmse :  0.0018949748853444002
# ### iteration step :  200  rmse :  0.001900297370519957
# ### iteration step :  200  rmse :  0.0018745850990396554
# ### iteration step :  200  rmse :  0.0018766719515830165
# ### iteration step :  200  rmse :  0.0018579964499579784
# ### iteration step :  200  rmse :  0.0018606716075532158
# ### iteration step :  200  rmse :  0.0018608757114975158
# ### iteration step :  200  rmse :  0.001870758685914867
# ### iteration step :  250  rmse :  0.000864076794515557
# ### iteration step :  250  rmse :  0.0008728496781734278
# ### iteration step :  250  rmse :  0.0008703605912005903
# ### iteration step :  250  rmse :  0.0008602260059504936
# ### iteration step :  250  rmse :  0.0008644845471949047
# ### iteration step :  250  rmse :  0.0008683162108334841
# ### iteration step :  250  rmse :  0.0008520148954149462
# ### iteration step :  250  rmse :  0.0008525674352660531
# ### iteration step :  250  rmse :  0.0008407530692084868
# ### iteration step :  250  rmse :  0.0008435629077471427
# ### iteration step :  250  rmse :  0.0008438785107490217
# ### iteration step :  250  rmse :  0.000855464736474408
# ### iteration step :  300  rmse :  0.0005143241246534952
# ### iteration step :  300  rmse :  0.0005218882618757992
# ### iteration step :  300  rmse :  0.0005186353379767983
# ### iteration step :  300  rmse :  0.0005122230435135367
# ### iteration step :  300  rmse :  0.0005162012423454883
# ### iteration step :  300  rmse :  0.0005188790798548887
# ### iteration step :  300  rmse :  0.0005069812016442326
# ### iteration step :  300  rmse :  0.0005069481115990985
# ### iteration step :  300  rmse :  0.0004970633085635687
# ### iteration step :  300  rmse :  0.0005002955354250139
# ### iteration step :  300  rmse :  0.0005014152551696716
# ### iteration step :  300  rmse :  0.000511714895592624
# ### iteration step :  350  rmse :  0.0003809122616329934
# ### iteration step :  350  rmse :  0.0003873655870732227
# ### iteration step :  350  rmse :  0.0003835971132253266
# ### iteration step :  350  rmse :  0.0003789705308620815
# ### iteration step :  350  rmse :  0.0003828160995562673
# ### iteration step :  350  rmse :  0.00038470978353665635
# ### iteration step :  350  rmse :  0.0003751346601583377
# ### iteration step :  350  rmse :  0.0003748488968867831
# ### iteration step :  350  rmse :  0.00036542292430784664
# ### iteration step :  350  rmse :  0.00036901701077469285
# ### iteration step :  350  rmse :  0.0003707790548357509
# ### iteration step :  350  rmse :  0.0003800018521624787
# ### iteration step :  400  rmse :  0.000325321305676004
# ### iteration step :  400  rmse :  0.00033092452585619796
# ### iteration step :  400  rmse :  0.00032683232043268954
# ### iteration step :  400  rmse :  0.00032312025146454264
# ### iteration step :  400  rmse :  0.00032690483017488336
# ### iteration step :  400  rmse :  0.0003282939168023716
# ### iteration step :  400  rmse :  0.0003200408824417673
# ### iteration step :  400  rmse :  0.0003196252678952413
# ### iteration step :  400  rmse :  0.00031019115068079117
# ### iteration step :  400  rmse :  0.0003140326837859814
# ### iteration step :  400  rmse :  0.00031619228522387146
# ### iteration step :  400  rmse :  0.0003248184034739271
# ### iteration step :  450  rmse :  0.00030046913095343303
# ### iteration step :  450  rmse :  0.0003054397594358233
# ### iteration step :  450  rmse :  0.0003011480950039647
# ### iteration step :  450  rmse :  0.0002979267238791366
# ### iteration step :  450  rmse :  0.00030168542117381137
# ### iteration step :  450  rmse :  0.00030275769823694614
# ### iteration step :  450  rmse :  0.00029530077064346974
# ### iteration step :  450  rmse :  0.0002948056890900125
# ### iteration step :  450  rmse :  0.0002852253434979073
# ### iteration step :  450  rmse :  0.000289225741303916
# ### iteration step :  450  rmse :  0.00029161684238388283
# ### iteration step :  450  rmse :  0.0002999715215258849
# ### iteration step :  500  rmse :  0.0002887147848385267
# ### iteration step :  500  rmse :  0.0002932111328972365
# ### iteration step :  500  rmse :  0.00028879549410954175
# ### iteration step :  500  rmse :  0.0002858490326224843
# ### iteration step :  500  rmse :  0.00028959890621861937
# ### iteration step :  500  rmse :  0.00029047330987473885
# ### iteration step :  500  rmse :  0.000283519303414401
# ### iteration step :  500  rmse :  0.00028296872668341183
# ### iteration step :  500  rmse :  0.00027321713911861737
# ### iteration step :  500  rmse :  0.0002773187052252513
# ### iteration step :  500  rmse :  0.0002798440932058089
# ### iteration step :  500  rmse :  0.0002881050620843007
# ### iteration step :  550  rmse :  0.00028287774231668724
# ### iteration step :  550  rmse :  0.0002870125789311842
# ### iteration step :  550  rmse :  0.00028251758065853144
# ### iteration step :  550  rmse :  0.0002797334637194737
# ### iteration step :  550  rmse :  0.0002834824977643708
# ### iteration step :  550  rmse :  0.00028423218800783503
# ### iteration step :  550  rmse :  0.00027761039831550777
# ### iteration step :  550  rmse :  0.0002770177767781233
# ### iteration step :  550  rmse :  0.00026710822962258994
# ### iteration step :  550  rmse :  0.0002712754208652871
# ### iteration step :  550  rmse :  0.00027388010216022456
# ### iteration step :  550  rmse :  0.0002821326446326989
# ### iteration step :  600  rmse :  0.0002798072395005609
# ### iteration step :  600  rmse :  0.000283661693578154
# ### iteration step :  600  rmse :  0.0002791134214055493
# ### iteration step :  600  rmse :  0.00027643237675990904
# ### iteration step :  600  rmse :  0.0002801839752244879
# ### iteration step :  600  rmse :  0.0002808534363198696
# ### iteration step :  600  rmse :  0.00027446075748694526
# ### iteration step :  600  rmse :  0.000273834796846996
# ### iteration step :  600  rmse :  0.000263791804134281
# ### iteration step :  600  rmse :  0.000268003094478047
# ### iteration step :  600  rmse :  0.00027065603783236856
# ### iteration step :  600  rmse :  0.0002789341866730162
# ### iteration step :  650  rmse :  0.0002780319915179904
# ### iteration step :  650  rmse :  0.00028166558434741183
# ### iteration step :  650  rmse :  0.00027707926495828015
# ### iteration step :  650  rmse :  0.00027447015425926174
# ### iteration step :  650  rmse :  0.0002782254364888111
# ### iteration step :  650  rmse :  0.0002788417147559163
# ### iteration step :  650  rmse :  0.0002726137065605426
# ### iteration step :  650  rmse :  0.00027196062624240176
# ### iteration step :  650  rmse :  0.00026181001054218964
# ### iteration step :  650  rmse :  0.00026605235859624197
# ### iteration step :  650  rmse :  0.00026873594791246703
# ### iteration step :  650  rmse :  0.00027704726688556014
# ### iteration step :  700  rmse :  0.0002768351047716055
# ### iteration step :  700  rmse :  0.00028029244591744876
# ### iteration step :  700  rmse :  0.00027567701549476237
# ### iteration step :  700  rmse :  0.00027312369481384156
# ### iteration step :  700  rmse :  0.0002768826805781003
# ### iteration step :  700  rmse :  0.0002774623566577761
# ### iteration step :  700  rmse :  0.00027135736946668713
# ### iteration step :  700  rmse :  0.0002706818793890775
# ### iteration step :  700  rmse :  0.00026044727953790494
# ### iteration step :  700  rmse :  0.00026471269655686694
# ### iteration step :  700  rmse :  0.0002674168506047029
# ### iteration step :  700  rmse :  0.0002757562491934786
# ### iteration step :  750  rmse :  0.000275860889661408
# ### iteration step :  750  rmse :  0.0002791760764923204
# ### iteration step :  750  rmse :  0.00027453684864575835
# ### iteration step :  750  rmse :  0.0002720311567862155
# ### iteration step :  750  rmse :  0.00027579337789243184
# ### iteration step :  750  rmse :  0.0002763467709049077
# ### iteration step :  750  rmse :  0.0002703369724086801
# ### iteration step :  750  rmse :  0.0002696427536058379
# ### iteration step :  750  rmse :  0.00025934461317772003
# ### iteration step :  750  rmse :  0.0002636281067340948
# ### iteration step :  750  rmse :  0.0002663470025631725
# ### iteration step :  750  rmse :  0.0002747041214088558
# ### iteration step :  800  rmse :  0.000274934918715963
# ### iteration step :  800  rmse :  0.0002781344509241725
# ### iteration step :  800  rmse :  0.0002734746600280053
# ### iteration step :  800  rmse :  0.0002710126346148604
# ### iteration step :  800  rmse :  0.0002747774464134007
# ### iteration step :  800  rmse :  0.00027531111599129
# ### iteration step :  800  rmse :  0.00026937729276175815
# ### iteration step :  800  rmse :  0.00026866726949532736
# ### iteration step :  800  rmse :  0.0002583227835779366
# ### iteration step :  800  rmse :  0.0002626211421440534
# ### iteration step :  800  rmse :  0.0002653513753849262
# ### iteration step :  800  rmse :  0.0002737143862568511
# ### iteration step :  850  rmse :  0.000273976284349213
# ### iteration step :  850  rmse :  0.0002770810335275112
# ### iteration step :  850  rmse :  0.00027240272324245213
# ### iteration step :  850  rmse :  0.0002699825523583285
# ### iteration step :  850  rmse :  0.00027374928733311536
# ### iteration step :  850  rmse :  0.0002742675165944947
# ### iteration step :  850  rmse :  0.0002683959925566947
# ### iteration step :  850  rmse :  0.00026767250697963286
# ### iteration step :  850  rmse :  0.00025729591892743083
# ### iteration step :  850  rmse :  0.0002616069964685507
# ### iteration step :  850  rmse :  0.00026434654036720876
# ### iteration step :  850  rmse :  0.00027270399767756454
# ### iteration step :  900  rmse :  0.00027295270717153745
# ### iteration step :  900  rmse :  0.00027597928283838686
# ### iteration step :  900  rmse :  0.00027128381625768843
# ### iteration step :  900  rmse :  0.0002689047344838901
# ### iteration step :  900  rmse :  0.0002726727729935972
# ### iteration step :  900  rmse :  0.00027317844904677167
# ### iteration step :  900  rmse :  0.0002673592153455673
# ### iteration step :  900  rmse :  0.0002666241506177822
# ### iteration step :  900  rmse :  0.000256227150480993
# ### iteration step :  900  rmse :  0.0002605494450126353
# ### iteration step :  900  rmse :  0.00026329705793492114
# ### iteration step :  900  rmse :  0.0002716387128792979
# ### iteration step :  950  rmse :  0.0002718568261342524
# ### iteration step :  950  rmse :  0.00027481855030823244
# ### iteration step :  950  rmse :  0.00027010690224584454
# ### iteration step :  950  rmse :  0.00026776860344469644
# ### iteration step :  950  rmse :  0.0002715374015725178
# ### iteration step :  950  rmse :  0.00027203254145089574
# ### iteration step :  950  rmse :  0.00026625809241226226
# ### iteration step :  950  rmse :  0.00026551296493956773
# ### iteration step :  950  rmse :  0.0002551050889364036
# ### iteration step :  950  rmse :  0.0002594374932656733
# ### iteration step :  950  rmse :  0.00026219238017526574
# ### iteration step :  950  rmse :  0.0002705094563858371

# %%
pred_matrix = np.dot(P, Q.T)
print("예측행렬: \n", np.round(pred_matrix, 3))
# Out:
# 예측행렬:
#  [[3.991 0.897 1.306 2.002 1.663]
#  [6.696 4.978 0.979 2.981 1.003]
#  [6.677 0.391 2.987 3.977 3.986]
#  [4.968 2.005 1.006 2.017 1.14 ]]
